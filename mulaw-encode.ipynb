# %%
# %load_ext autoreload
# %autoreload 2
import librosa 
from generic_utils import load_config
from audio import AudioProcessor
wav, sr = librosa.core.load("/data/shared/KeithIto/LJSpeech-1.0/wavs/LJ040-0084.wav") 
C = load_config('conf.json')
ap = AudioProcessor(C.sample_rate, C.num_mels, C.min_level_db, C.frame_shift_ms, C.frame_length_ms, C.preemphasis, C.ref_level_db)

# %%
qc = 2 ** 8
wav_en = ap.mulaw_encode(wav, qc)
wav_de = ap.mulaw_decode(wav_en, qc)

# %%
import IPython
IPython.display.display(IPython.display.Audio(wav, rate=sr))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython
IPython.display.display(IPython.display.Audio(wav_en, rate=sr))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython
IPython.display.display(IPython.display.Audio(wav_de, rate=sr))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
