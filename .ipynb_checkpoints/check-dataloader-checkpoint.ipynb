# %%
# %load_ext autoreload
# %autoreload 2
import os
import torch
import unittest
import time
import pickle
import copy
import numpy as np
from torch import optim
from torch.utils.data import DataLoader
from generic_utils import load_config
from model import FFTNet, FFTNetModel
from dataset import LJSpeechDataset

torch.manual_seed(1)
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
MAX = 100
C = load_config('test_conf.json')
with open(f"{C.data_path}dataset_ids.pkl", "rb") as f:
        dataset_ids = pickle.load(f)
dataset = LJSpeechDataset(dataset_ids, 
                          C.data_path, 
                          11, C.min_wav_len, C.max_wav_len, False)
dataloader = DataLoader(dataset, batch_size=2,
                        shuffle=False, collate_fn=dataset.collate_fn,
                        drop_last=True, num_workers=2)
# Out:
#  > Reading LJSpeech from - runs/fftnet/data/mels
#  | > Number of instances : 45
#  | > Max wav length: 5000
#  | > Min wav length: 0
#  | > Receptive field: 2048

# %%
A = 5
c = 0
for data in dataloader:
    wav = data[0]
    mel = data[1]
    leng = data[2]
    target = data[3]
    c += 1
    print(c)
    if c == A:
        break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-8934855b7dbd> in <module>()
#       1 A = 5
#       2 c = 0
# ----> 3 for data in dataloader:
#       4     wav = data[0]
#       5     mel = data[1]
#
# ~/miniconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     334                 self.reorder_dict[idx] = batch
#     335                 continue
# --> 336             return self._process_next_batch(batch)
#     337
#     338     next = __next__  # Python 2 compatibility
#
# ~/miniconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _process_next_batch(self, batch)
#     355         self._put_indices()
#     356         if isinstance(batch, ExceptionWrapper):
# --> 357             raise batch.exc_type(batch.exc_msg)
#     358         return batch
#     359
#
# FileNotFoundError: Traceback (most recent call last):
#   File "/home/erogol/miniconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/erogol/miniconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/erogol/Projects/FFTNet/dataset.py", line 41, in __getitem__
#     m = np.load(f"{self.data_dir}mel/{file}.npy")
#   File "/home/erogol/miniconda3/lib/python3.6/site-packages/numpy/lib/npyio.py", line 372, in load
#     fid = open(file, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/fftnet/data/melsmel/r.npy'

# %%
from matplotlib import pylab as plt
plt.plot(np.array(wav[0]))

# %%
from matplotlib import pylab as plt
plt.plot(np.array(target[0]))

# %%
wav = wav.type_as(target)

# %%
abs(wav[0, dataset.receptive_field:] - target[0, :-1]).sum()
# Out:
# tensor(0)

# %%
wav[0, dataset.receptive_field:] - target[0, :-1]
# Out:
# tensor([ 0,  0,  0,  ...,  0,  0,  0])

# %%
assert abs(wav[0, dataset.receptive_field:] - target[0, :-1]).sum() == 0

# %%
from visual import plot_spectrogram
plot_spectrogram(mel[1].numpy(), dataset.ap);
